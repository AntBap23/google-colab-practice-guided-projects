# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ['A', 'B', 'C'], index = ['x','y','z'])

# %%
df = pd.read_excel('olympics-data.xlsx')
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee = pd.read_csv('coffee.csv')

# %%
coffee['price'] = 4.99
coffee['price'] = np.where(coffee["Coffee Type"] == 'Espresso', 4.99, 5.99)
coffee['new_price'] = 7.99
coffee = coffee.drop(columns = ['new_price'])

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['price']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   4.99   124.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   4.99   149.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   4.99   174.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   4.99   199.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   4.99   224.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   4.99   224.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   4.99   224.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
df['first_name'] = df['name'].str.split(' ').str[0]
df['last_name'] = df['name'].str.split(' ').str[1]

df[['first_name', 'last_name']]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
#  11  last_name     145500 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 13.3+ MB

# %%
df['born_date'] = pd.to_datetime(df['born_date'])
df['born_year'] = df['born_date'].dt.year

df['height_category'] = df['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))

def categorize_athlete(row):
    if row['height_cm'] < 165 and row['weight_kg'] < 70:
        return 'LightWeight'
    elif row['height_cm'] < 185 and row['weight_kg'] < 90:
        return 'Average'
    else:
        return 'Heavy'

df['athlete_category'] = df.apply(categorize_athlete, axis=1)

df[df['athlete_category'] == 'LightWeight']
# Out:
#         athlete_id                   name  born_date        born_city  \
# 49              50         Gillian Gowers 1964-04-09              NaN
# 62              63          Jo Muggeridge 1969-04-03           London
# 128            129             Olga Nemes 1968-06-09      Târgu Mureș
# 171            172  Christina Zachariadou 1974-08-28  Athina (Athens)
# 192            193            Hui So Hung 1958-12-02              NaN
# ...            ...                    ...        ...              ...
# 144753      148454    Ioulia Chtchetinina 1995-12-24  Nizhny Novgorod
# 144766      148467         Lara Della Mea 1999-01-10          Trieste
# 144796      148497       Sofia Belingheri 1995-04-24          Bergamo
# 145474      149201      Nadine Hofstetter 1994-10-21           Romoos
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
#
#             born_region born_country                   NOC  height_cm  \
# ...

# %%
coffee.loc[[0,1], 'Units Sold'] = np.nan
coffee.fillna(coffee['Units Sold'].mean(), inplace = True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   4.99   124.75
# 1      Monday       Latte        35.0   5.99    89.85
# 2     Tuesday    Espresso        30.0   4.99   149.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   4.99   174.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   4.99   199.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   4.99   224.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   4.99   224.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   4.99   224.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
df[df['born_country'] == 'USA'][['born_region', 'born_city']].value_counts().head()
# Out:
# born_region    born_city
# New York       New York        416
# Illinois       Chicago         283
# California     Los Angeles     230
# Pennsylvania   Philadelphia    205
# Massachusetts  Boston          153
# Name: count, dtype: int64

# %%
coffee.groupby('Coffee Type')['price'].mean()
# Out:
# Coffee Type
# Espresso    4.99
# Latte       5.99
# Name: price, dtype: float64

# %%
df.groupby(['born_year'])['name'].count().reset_index().sort_values('name', ascending = False).tail()
# Out:
#      born_year  name
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(1)
coffee['revenue_diff'] = coffee['revenue'] - coffee['yesterday_revenue']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        35.0   4.99   124.75                NaN
# 1      Monday       Latte        35.0   5.99    89.85             124.75
# 2     Tuesday    Espresso        30.0   4.99   149.70              89.85
# 3     Tuesday       Latte        20.0   5.99   119.80             149.70
# 4   Wednesday    Espresso        35.0   4.99   174.65             119.80
# 5   Wednesday       Latte        25.0   5.99   149.75             174.65
# 6    Thursday    Espresso        40.0   4.99   199.60             149.75
# 7    Thursday       Latte        30.0   5.99   179.70             199.60
# 8      Friday    Espresso        45.0   4.99   224.55             179.70
# 9      Friday       Latte        35.0   5.99   209.65             224.55
# 10   Saturday    Espresso        45.0   4.99   224.55             209.65
# 11   Saturday       Latte        35.0   5.99   209.65             224.55
# ...

# %%
df['height_rank'] = df['height_cm'].rank(ascending = False)
df.sort_values('height_rank').sample(10)[['name', 'height_rank']]
# Out:
#                      name  height_rank
# 136355   Konrad Kudeviita          NaN
# 30469   Mathias Weishaupt          NaN
# 29387     Georg Albertsen          NaN
# 111706         Nick Okoth      96305.5
# 10849   František Svoboda          NaN
# 92198        Miguel Nunes      38677.0
# 125351  Eetu Vähäsöyrinki      66080.0
# 2240    William Valentine          NaN
# 130806         Anas Beshr          NaN
# 71429      Disma Ferrario          NaN

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
latte['3_day_Units'] = latte['Units Sold'].rolling(3).sum()
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 1      Monday       Latte        35.0   5.99    89.85             124.75
# 3     Tuesday       Latte        20.0   5.99   119.80             149.70
# 5   Wednesday       Latte        25.0   5.99   149.75             174.65
# 7    Thursday       Latte        30.0   5.99   179.70             199.60
# 9      Friday       Latte        35.0   5.99   209.65             224.55
# 11   Saturday       Latte        35.0   5.99   209.65             224.55
# 13     Sunday       Latte        35.0   5.99   209.65             224.55
#
#     revenue_diff  3_day_Units
# 1          -34.9          NaN
# 3          -29.9          NaN
# 5          -24.9         80.0
# 7          -19.9         75.0
# 9          -14.9         90.0
# 11         -14.9        100.0
# 13         -14.9        105.0
